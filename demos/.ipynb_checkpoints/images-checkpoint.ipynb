# %% [markdown]
# # Image segmentation demo
#
# This notebook shows how to build and train a KuraNet instance for learning couplings which promote cluster synchrony corresponding to segments in a natural image. We will consider an equilibrium Kuramoto model of the form $$\dot{\theta_i} = \sum_j K_{ij}\sin(\theta_j(t) - \theta_i(t))$$
# where $(K)_{ij} \in \mathcal{K}$ is an $n \times n$ coupling matrix. Each oscillator, $i$, is associated to an i.i.d. random feature $x_i\in \mathbb{R}^5 \subset \mathcal{X}$ which has a label $y_i = y(x_i) \in {1, \ldots, k}$. The feature, $x_i$, consists of the three RGB values at a given pixel together with its coordinates in the image. Absuing terminology, we consider these random features to be the "quenched disorder" of KuraNet since they affect the long-term learning dynamics, even if they don't influence the short-term evolution.
#
# We will use a deep neural network to approximate the function $\mathcal{X}^n \times \mathcal{X}^n \to \mathcal{K}$ that makes the oscillators synchronize into clusters respecting the labels, $y_i$. This deep neural network is trained to produe couplings which minimize the circular variance within each group and a potential measuring desynchrony between all groups. If target cluster $l$, has mean phase $\langle \theta \rangle_l(t)$, the desynchrony potential is $$S= \lim_{t\to \infty} \sum_g^k \frac{1}{2g^2k}\left| \sum_l^k e^{ig\langle \theta \rangle_l(t)}\right|^2.$$
#
# First, we load some modules and set the CUDA device.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import torch
from torch.utils.data import DataLoader
from torch.utils.data.dataset import TensorDataset
import os
import sys
import inspect

currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0, parentdir) 

from models import KuraNet
from train import optimize_connectivity_net
from data import make_data, get_BSDS_info
from utils import circular_variance, circular_moments, cohn_loss, make_masks
from skimage.io import imread
import cv2 as cv

# Set CUDA device
os.environ['CUDA_DEVICE_ORDER']='PCI_BUS_ID'
os.environ['CUDA_VISIBLE_DEVICES']='0'

# %% [markdown]
# ## Make data and set parameters
#
# Next we generate and save the image data. By default, the following cell will download and unzip a tar.gz file into your home directory containing the BSDS image data. Set the keyword `download` to False to prevent this.  Images are denoted by a six-digit tag.

# %%
from os.path import expanduser
home = expanduser("~")
data_base_dir = os.path.join(home,'cluster_synchrony1')
if not os.path.exists(data_base_dir): os.makedirs(data_base_dir)
    
full_BSDS_path = os.path.join(home, 'BSDS/BSR/BSDS500/data/')
data_names=['BSDS']
dist_names = ['229036'] #90076, 118020, 124084, 189011, 229036, 247003, 296028, 317080, 361010

# Uncomment this line to generate data
make_data(data_names[0], dist_names[0], data_base_dir=data_base_dir, download=True)

# make_all_data(num_samples=args.num_samples,data_dir=args.data_dir)
# Out:
# True

# %%
seed=0
model_type='xy'
num_samples=10000
num_epochs=3
num_units=100
batch_size=100
feature_dim=5
num_hid_units=128
symmetric=True
normalize='graph'
device='cuda'
adjoint=False
solver_method='euler'
optimizer='Adam'
max_grad_norm=1.0
lr=1e-5
momentum=0.0
loss_type='circular_moments'
alpha=15
gd_steps=100
burn_in_steps=50
measure_cx=False
set_gain=True
gain=.5
initial_phase='normal'

num_batches = int(num_samples/num_units)

 # Set loss function
if loss_type == 'circular_variance':
    loss_func = circular_variance
elif loss_type == 'circular_moments':
    loss_func = circular_moments
elif loss_type == 'cohn_loss':
    loss_func = cohn_loss
else:
    raise Exception('Loss type not recognized.')
    
train_dls  = {}
test_dls   = {}
train_dts    = {}
test_dts     = {}

# Load training and testing data.
for dl, dt, regime in zip([train_dls, test_dls], [train_dts, test_dts],['train', 'test']):
    for dist_name, data_name in zip(dist_names, data_names):
        dt[data_name] = {}
        if dist_name != 'degenerate':
            dt[data_name][regime] = np.load(os.path.join(data_base_dir, data_name, dist_name, regime, 'features.npz'))
            ds = TensorDataset(torch.FloatTensor(dt[data_name][regime]['x']), torch.LongTensor(dt[data_name][regime]['y'].astype(np.int32)))
        else:
            dt[data_name][regime] = {'x': torch.zeros(num_samples,1).float(), 'y' : torch.zeros(num_samples).long()}
            ds = TensorDataset(torch.zeros(num_samples,1).float(), torch.zeros(num_samples).long())
        dl[data_name] = DataLoader(ds, batch_size=num_units, shuffle=True, drop_last=True)

num_classes= len(set(dt[data_names[0]]['test']['y']).union(set(dt[data_names[0]]['test']['y'])))
data_keys = [key for key in train_dls.keys()]

# %% [markdown]
# ## Training KuraNet
#
# This cell trains the model on the selected experiment over `num_epochs` passes over the whole node feature data set. On each iteration, a sample of node features is drawn and then passed through the neural network that produces couplings. These couplings then participate in a Kuramoto dynamics whose final steps are evaluated by the specified loss function.

# %%
np.random.seed(seed)
torch.manual_seed(seed)

loss_train, loss_test, kn, cx = optimize_connectivity_net(num_units, feature_dim, train_dls, test_dls, model_type=model_type,
                                                          num_classes=num_classes, avg_deg=1.0, normalize=normalize,
                                                          symmetric=symmetric, pretrained=False, num_epochs=num_epochs,
                                                          batch_size=num_units, 
                                                          burn_in_steps=burn_in_steps, gd_steps=gd_steps,
                                                          alpha=alpha, solver_method=solver_method, adjoint=adjoint,
                                                          loss_type=loss_type, optimizer=optimizer,
                                                          lr=lr, momentum=momentum, max_grad_norm=max_grad_norm,
                                                          num_hid_units=num_hid_units, verbose=1, show_every=10,
                                                          num_eval_batches=10, rand_inds=False,
                                                          set_gain=True, gain=gain, initial_phase=initial_phase,
                                                          device=device)
# Out:
# Training. Epoch 0.
# Training batch: 0. Time/Batch: 6.9297. Loss: 0.4757838249206543. Gradient norm: 1.0.
# Training batch: 10. Time/Batch: 0.729. Loss: 0.3125367760658264. Gradient norm: 1.0.
# Training batch: 20. Time/Batch: 0.6664. Loss: 0.282709538936615. Gradient norm: 1.0.
# Training batch: 30. Time/Batch: 0.694. Loss: 0.27520236372947693. Gradient norm: 1.0.
# Training batch: 40. Time/Batch: 3.8426. Loss: 0.23444660007953644. Gradient norm: 1.0.
# Training batch: 50. Time/Batch: 0.9178. Loss: 0.2424129843711853. Gradient norm: 1.0.
# Training batch: 60. Time/Batch: 0.5091. Loss: 0.31138139963150024. Gradient norm: 1.0.
# Training batch: 70. Time/Batch: 3.3893. Loss: 0.3345034718513489. Gradient norm: 1.0.
# Training batch: 80. Time/Batch: 1.3938. Loss: 0.2431824505329132. Gradient norm: 1.0.
# Training batch: 90. Time/Batch: 3.6873. Loss: 0.2572043240070343. Gradient norm: 1.0.
# Training batch: 100. Time/Batch: 2.1421. Loss: 0.21798507869243622. Gradient norm: 1.0.
# Training batch: 110. Time/Batch: 2.7581. Loss: 0.28996750712394714. Gradient norm: 1.0.
# Training batch: 120. Time/Batch: 0.7716. Loss: 0.31197312474250793. Gradient norm: 1.0.
# Training batch: 130. Time/Batch: 1.1223. Loss: 0.21351462602615356. Gradient norm: 1.0.
# Training batch: 140. Time/Batch: 4.232. Loss: 0.25315049290657043. Gradient norm: 1.0.
# Training batch: 150. Time/Batch: 0.6411. Loss: 0.24259154498577118. Gradient norm: 1.0.
# Training batch: 160. Time/Batch: 4.5323. Loss: 0.1890115737915039. Gradient norm: 1.0.
# Training batch: 170. Time/Batch: 3.224. Loss: 0.15192018449306488. Gradient norm: 1.0.
# Training batch: 180. Time/Batch: 2.6094. Loss: 0.13611383736133575. Gradient norm: 1.0.
# Training batch: 190. Time/Batch: 4.2731. Loss: 0.15441544353961945. Gradient norm: 1.0.
# Training batch: 200. Time/Batch: 0.3873. Loss: 0.24686595797538757. Gradient norm: 1.0.
# Training batch: 210. Time/Batch: 1.0006. Loss: 0.2165461629629135. Gradient norm: 1.0.
# Training batch: 220. Time/Batch: 0.8056. Loss: 0.1858309954404831. Gradient norm: 1.0.
# Training batch: 230. Time/Batch: 1.0974. Loss: 0.19460995495319366. Gradient norm: 1.0.
# Training batch: 240. Time/Batch: 5.163. Loss: 0.12575116753578186. Gradient norm: 1.0.
# Training batch: 250. Time/Batch: 1.1506. Loss: 0.11602757126092911. Gradient norm: 1.0.
# Training batch: 260. Time/Batch: 0.4811. Loss: 0.14179696142673492. Gradient norm: 1.0.
# Training batch: 270. Time/Batch: 0.3782. Loss: 0.17284135520458221. Gradient norm: 1.0.
# Training batch: 280. Time/Batch: 1.0824. Loss: 0.1850339025259018. Gradient norm: 1.0.
# Training batch: 290. Time/Batch: 0.6323. Loss: 0.13605806231498718. Gradient norm: 1.0.
# Training batch: 300. Time/Batch: 4.3107. Loss: 0.21892791986465454. Gradient norm: 1.0.
# Training batch: 310. Time/Batch: 1.3198. Loss: 0.1646987944841385. Gradient norm: 1.0.
# Training batch: 320. Time/Batch: 3.2445. Loss: 0.1366651952266693. Gradient norm: 1.0.
# Training batch: 330. Time/Batch: 0.7965. Loss: 0.21313151717185974. Gradient norm: 1.0.
# Training batch: 340. Time/Batch: 2.9725. Loss: 0.1410689651966095. Gradient norm: 1.0.
# Training batch: 350. Time/Batch: 0.5177. Loss: 0.13059595227241516. Gradient norm: 1.0.
# Training batch: 360. Time/Batch: 0.6864. Loss: 0.10562828183174133. Gradient norm: 1.0.
# Training batch: 370. Time/Batch: 2.7709. Loss: 0.22541171312332153. Gradient norm: 1.0.
# Training batch: 380. Time/Batch: 0.4735. Loss: 0.21589648723602295. Gradient norm: 1.0.
# Training batch: 390. Time/Batch: 0.57. Loss: 0.12893730401992798. Gradient norm: 1.0.
# Training batch: 400. Time/Batch: 1.0009. Loss: 0.15771245956420898. Gradient norm: 1.0.
# Training batch: 410. Time/Batch: 0.9443. Loss: 0.11534379422664642. Gradient norm: 1.0.
# Training batch: 420. Time/Batch: 0.6813. Loss: 0.11187877506017685. Gradient norm: 1.0.
# Training batch: 430. Time/Batch: 4.3392. Loss: 0.0990828201174736. Gradient norm: 1.0.
# Training batch: 440. Time/Batch: 0.569. Loss: 0.10003604739904404. Gradient norm: 1.0.
# Training batch: 450. Time/Batch: 0.9851. Loss: 0.07955706864595413. Gradient norm: 1.0.
# Training batch: 460. Time/Batch: 0.459. Loss: 0.12276281416416168. Gradient norm: 1.0.
# Training batch: 470. Time/Batch: 0.8328. Loss: 0.0671045258641243. Gradient norm: 1.0.
# Training batch: 480. Time/Batch: 0.7333. Loss: 0.11249276250600815. Gradient norm: 1.0.
# Training batch: 490. Time/Batch: 0.8874. Loss: 0.12563417851924896. Gradient norm: 1.0.
# Training batch: 500. Time/Batch: 0.4423. Loss: 0.19251789152622223. Gradient norm: 1.0.
# Training batch: 510. Time/Batch: 0.7258. Loss: 0.08829685300588608. Gradient norm: 1.0.
# Training batch: 520. Time/Batch: 1.4082. Loss: 0.048879820853471756. Gradient norm: 1.0.
# Training batch: 530. Time/Batch: 0.361. Loss: 0.09698465466499329. Gradient norm: 1.0.
# Training batch: 540. Time/Batch: 0.7307. Loss: 0.09515462815761566. Gradient norm: 1.0.
# Training batch: 550. Time/Batch: 4.7724. Loss: 0.12360761314630508. Gradient norm: 1.0.
# Training batch: 560. Time/Batch: 0.6101. Loss: 0.053314514458179474. Gradient norm: 1.0.
# Training batch: 570. Time/Batch: 0.7837. Loss: 0.11041581630706787. Gradient norm: 1.0.
# Training batch: 580. Time/Batch: 1.1274. Loss: 0.08072179555892944. Gradient norm: 1.0.
# Training batch: 590. Time/Batch: 0.7123. Loss: 0.07756061106920242. Gradient norm: 1.0.
# Training batch: 600. Time/Batch: 1.0465. Loss: 0.11264944076538086. Gradient norm: 1.0.
# Training batch: 610. Time/Batch: 2.3744. Loss: 0.16826173663139343. Gradient norm: 1.0.
# Training batch: 620. Time/Batch: 0.8505. Loss: 0.08278097212314606. Gradient norm: 1.0.
# Training batch: 630. Time/Batch: 0.6187. Loss: 0.0774894505739212. Gradient norm: 1.0.
# Training batch: 640. Time/Batch: 1.2912. Loss: 0.08880703896284103. Gradient norm: 1.0.
# Training batch: 650. Time/Batch: 2.3376. Loss: 0.09087542444467545. Gradient norm: 1.0.
# Training batch: 660. Time/Batch: 0.7107. Loss: 0.08862888813018799. Gradient norm: 1.0.
# Training batch: 670. Time/Batch: 2.4258. Loss: 0.04766859859228134. Gradient norm: 1.0.
# Training batch: 680. Time/Batch: 2.4378. Loss: 0.0863906741142273. Gradient norm: 1.0.
# Training batch: 690. Time/Batch: 1.9089. Loss: 0.08286981284618378. Gradient norm: 1.0.
# Training batch: 700. Time/Batch: 1.4934. Loss: 0.07081767916679382. Gradient norm: 1.0.
# Training batch: 710. Time/Batch: 0.8891. Loss: 0.04641260206699371. Gradient norm: 1.0.
# Training batch: 720. Time/Batch: 0.6598. Loss: 0.11338088661432266. Gradient norm: 1.0.
# Training batch: 730. Time/Batch: 4.4553. Loss: 0.06558256596326828. Gradient norm: 1.0.
# Training batch: 740. Time/Batch: 0.9842. Loss: 0.0570245236158371. Gradient norm: 1.0.
# Training batch: 750. Time/Batch: 0.8596. Loss: 0.0923578217625618. Gradient norm: 1.0.
# Training batch: 760. Time/Batch: 3.657. Loss: 0.0895984023809433. Gradient norm: 1.0.
# Training batch: 770. Time/Batch: 0.6525. Loss: 0.04904921352863312. Gradient norm: 1.0.
# Testing. Epoch 0
# Testing batch: 0. Time/Batch: 0.1876. Loss: 0.08257222920656204.
# Testing batch: 10. Time/Batch: 0.6925. Loss: 0.14767827093601227.
# Training. Epoch 1.
# Training batch: 0. Time/Batch: 3.0371. Loss: 0.07073858380317688. Gradient norm: 1.0.
# Training batch: 10. Time/Batch: 0.4066. Loss: 0.03395010903477669. Gradient norm: 1.0.
# Training batch: 20. Time/Batch: 0.6398. Loss: 0.06615783274173737. Gradient norm: 0.8990557493447271.
# Training batch: 30. Time/Batch: 1.5973. Loss: 0.06588568538427353. Gradient norm: 1.0.
# Training batch: 40. Time/Batch: 0.3792. Loss: 0.05328778177499771. Gradient norm: 1.0.
# Training batch: 50. Time/Batch: 3.0315. Loss: 0.05951125919818878. Gradient norm: 1.0.
# Training batch: 60. Time/Batch: 0.7558. Loss: 0.06018002703785896. Gradient norm: 1.0.
# Training batch: 70. Time/Batch: 1.3306. Loss: 0.04393254593014717. Gradient norm: 0.8478557608791818.
# Training batch: 80. Time/Batch: 4.6755. Loss: 0.08078572899103165. Gradient norm: 1.0.
# Training batch: 90. Time/Batch: 1.6027. Loss: 0.047283973544836044. Gradient norm: 1.0.
# Training batch: 100. Time/Batch: 2.0385. Loss: 0.060267526656389236. Gradient norm: 1.0.
# Training batch: 110. Time/Batch: 2.9476. Loss: 0.05522789806127548. Gradient norm: 1.0.
# Training batch: 120. Time/Batch: 2.9085. Loss: 0.060283076018095016. Gradient norm: 1.0.
# Training batch: 130. Time/Batch: 0.359. Loss: 0.07081683725118637. Gradient norm: 1.0.
# Training batch: 140. Time/Batch: 0.8835. Loss: 0.05158840864896774. Gradient norm: 1.0.
# Training batch: 150. Time/Batch: 3.4724. Loss: 0.09139487892389297. Gradient norm: 1.0.
# Training batch: 160. Time/Batch: 0.417. Loss: 0.0383475236594677. Gradient norm: 1.0.
# Training batch: 170. Time/Batch: 2.4919. Loss: 0.07122194766998291. Gradient norm: 1.0.
# Training batch: 180. Time/Batch: 0.8336. Loss: 0.035360511392354965. Gradient norm: 1.0.
# Training batch: 190. Time/Batch: 0.6417. Loss: 0.05068821832537651. Gradient norm: 1.0.
# Training batch: 200. Time/Batch: 3.6632. Loss: 0.06994664669036865. Gradient norm: 1.0.
# Training batch: 210. Time/Batch: 0.4369. Loss: 0.053167447447776794. Gradient norm: 1.0.
# Training batch: 220. Time/Batch: 3.5372. Loss: 0.09346097707748413. Gradient norm: 1.0.
# Training batch: 230. Time/Batch: 0.6526. Loss: 0.05843854695558548. Gradient norm: 1.0.
# Training batch: 240. Time/Batch: 1.0453. Loss: 0.05058671906590462. Gradient norm: 1.0.
# Training batch: 250. Time/Batch: 4.0625. Loss: 0.03487410023808479. Gradient norm: 1.0.
# Training batch: 260. Time/Batch: 0.9969. Loss: 0.06854749470949173. Gradient norm: 1.0.
# Training batch: 270. Time/Batch: 3.0975. Loss: 0.043690554797649384. Gradient norm: 1.0.
# Training batch: 280. Time/Batch: 0.502. Loss: 0.05211147665977478. Gradient norm: 1.0.
# Training batch: 290. Time/Batch: 0.5259. Loss: 0.04170876741409302. Gradient norm: 1.0.
# Training batch: 300. Time/Batch: 0.6475. Loss: 0.0522809773683548. Gradient norm: 1.0.
# Training batch: 310. Time/Batch: 0.612. Loss: 0.079341359436512. Gradient norm: 1.0.
# Training batch: 320. Time/Batch: 3.929. Loss: 0.07462552934885025. Gradient norm: 1.0.
# Training batch: 330. Time/Batch: 0.7608. Loss: 0.06191480532288551. Gradient norm: 1.0.
# Training batch: 340. Time/Batch: 0.5867. Loss: 0.05651964247226715. Gradient norm: 1.0.
# Training batch: 350. Time/Batch: 2.3997. Loss: 0.05331724137067795. Gradient norm: 1.0.
# Training batch: 360. Time/Batch: 0.8641. Loss: 0.07938942313194275. Gradient norm: 1.0.
# Training batch: 370. Time/Batch: 3.7353. Loss: 0.07011983543634415. Gradient norm: 1.0.
# Training batch: 380. Time/Batch: 0.4781. Loss: 0.04005805775523186. Gradient norm: 1.0.
# Training batch: 390. Time/Batch: 0.6108. Loss: 0.07811322063207626. Gradient norm: 1.0.
# Training batch: 400. Time/Batch: 3.8122. Loss: 0.0407954677939415. Gradient norm: 1.0.
# Training batch: 410. Time/Batch: 1.3803. Loss: 0.054199762642383575. Gradient norm: 1.0.
# Training batch: 420. Time/Batch: 3.4774. Loss: 0.044333070516586304. Gradient norm: 1.0.
# Training batch: 430. Time/Batch: 0.7856. Loss: 0.05420509725809097. Gradient norm: 1.0.
# Training batch: 440. Time/Batch: 0.4053. Loss: 0.06762631237506866. Gradient norm: 1.0.
# Training batch: 450. Time/Batch: 0.9688. Loss: 0.06738190352916718. Gradient norm: 1.0.
# Training batch: 460. Time/Batch: 0.7593. Loss: 0.08688701689243317. Gradient norm: 1.0.
# Training batch: 470. Time/Batch: 5.2306. Loss: 0.08530177175998688. Gradient norm: 1.0.
# Training batch: 480. Time/Batch: 0.8155. Loss: 0.0651259571313858. Gradient norm: 1.0.
# Training batch: 490. Time/Batch: 0.673. Loss: 0.06118066981434822. Gradient norm: 1.0.
# Training batch: 500. Time/Batch: 1.1767. Loss: 0.07378191500902176. Gradient norm: 1.0.
# Training batch: 510. Time/Batch: 0.6553. Loss: 0.03736276924610138. Gradient norm: 1.0.
# Training batch: 520. Time/Batch: 0.7525. Loss: 0.06124810874462128. Gradient norm: 1.0.
# Training batch: 530. Time/Batch: 1.3707. Loss: 0.042837534099817276. Gradient norm: 1.0.
# Training batch: 540. Time/Batch: 0.8487. Loss: 0.08764329552650452. Gradient norm: 1.0.
# Training batch: 550. Time/Batch: 0.7082. Loss: 0.0643952414393425. Gradient norm: 1.0.
# Training batch: 560. Time/Batch: 4.1969. Loss: 0.05830375850200653. Gradient norm: 1.0.
# Training batch: 570. Time/Batch: 1.4762. Loss: 0.06979808956384659. Gradient norm: 1.0.
# Training batch: 580. Time/Batch: 2.2078. Loss: 0.031802620738744736. Gradient norm: 1.0.
# Training batch: 590. Time/Batch: 2.9478. Loss: 0.04851179197430611. Gradient norm: 1.0.
# Training batch: 600. Time/Batch: 1.4646. Loss: 0.056127071380615234. Gradient norm: 1.0.
# Training batch: 610. Time/Batch: 0.7431. Loss: 0.032372523099184036. Gradient norm: 1.0.
# Training batch: 620. Time/Batch: 3.395. Loss: 0.096872977912426. Gradient norm: 1.0.
# Training batch: 630. Time/Batch: 0.7827. Loss: 0.04122836887836456. Gradient norm: 0.8833859350865728.
# Training batch: 640. Time/Batch: 3.1718. Loss: 0.04428417235612869. Gradient norm: 1.0.
# Training batch: 650. Time/Batch: 3.9816. Loss: 0.05274323374032974. Gradient norm: 1.0.
# Training batch: 660. Time/Batch: 1.8797. Loss: 0.045963190495967865. Gradient norm: 1.0.
# Training batch: 670. Time/Batch: 0.9555. Loss: 0.04151226580142975. Gradient norm: 1.0.
# Training batch: 680. Time/Batch: 0.7693. Loss: 0.03398358076810837. Gradient norm: 1.0.
# Training batch: 690. Time/Batch: 2.207. Loss: 0.051801469177007675. Gradient norm: 1.0.
# Training batch: 700. Time/Batch: 0.6227. Loss: 0.06335780769586563. Gradient norm: 1.0.
# Training batch: 710. Time/Batch: 0.9149. Loss: 0.09014062583446503. Gradient norm: 1.0.
# Training batch: 720. Time/Batch: 0.5298. Loss: 0.04722995311021805. Gradient norm: 1.0.
# Training batch: 730. Time/Batch: 1.0105. Loss: 0.06729849427938461. Gradient norm: 1.0.
# Training batch: 740. Time/Batch: 2.9763. Loss: 0.0464673712849617. Gradient norm: 1.0.
# Training batch: 750. Time/Batch: 0.7797. Loss: 0.05236383154988289. Gradient norm: 1.0.
# Training batch: 760. Time/Batch: 0.4687. Loss: 0.050856541842222214. Gradient norm: 1.0.
# Training batch: 770. Time/Batch: 0.7749. Loss: 0.0809851884841919. Gradient norm: 1.0.
# Testing. Epoch 1
# Testing batch: 0. Time/Batch: 0.5048. Loss: 0.050137270241975784.
# Testing batch: 10. Time/Batch: 0.2198. Loss: 0.033659689128398895.
# Training. Epoch 2.
# Training batch: 0. Time/Batch: 0.3771. Loss: 0.02590332180261612. Gradient norm: 1.0.
# Training batch: 10. Time/Batch: 0.6506. Loss: 0.05869678407907486. Gradient norm: 1.0.
# Training batch: 20. Time/Batch: 0.443. Loss: 0.04054665565490723. Gradient norm: 1.0.
# Training batch: 30. Time/Batch: 0.7896. Loss: 0.06056263670325279. Gradient norm: 1.0.
# Training batch: 40. Time/Batch: 3.2106. Loss: 0.04694391041994095. Gradient norm: 1.0.
# Training batch: 50. Time/Batch: 0.78. Loss: 0.04281623288989067. Gradient norm: 1.0.
# Training batch: 60. Time/Batch: 0.7835. Loss: 0.07376717031002045. Gradient norm: 1.0.
# Training batch: 70. Time/Batch: 1.7126. Loss: 0.04755225405097008. Gradient norm: 1.0.
# Training batch: 80. Time/Batch: 0.3804. Loss: 0.12747180461883545. Gradient norm: 1.0.
# Training batch: 90. Time/Batch: 1.038. Loss: 0.08103823661804199. Gradient norm: 1.0.
# Training batch: 100. Time/Batch: 0.8813. Loss: 0.06405657529830933. Gradient norm: 1.0.
# Training batch: 110. Time/Batch: 0.7503. Loss: 0.062039874494075775. Gradient norm: 1.0.
# Training batch: 120. Time/Batch: 4.7494. Loss: 0.05654482543468475. Gradient norm: 1.0.
# Training batch: 130. Time/Batch: 1.5218. Loss: 0.03772735968232155. Gradient norm: 1.0.
# Training batch: 140. Time/Batch: 0.7598. Loss: 0.04390522837638855. Gradient norm: 1.0.
# Training batch: 150. Time/Batch: 0.3566. Loss: 0.0732574388384819. Gradient norm: 1.0.
# Training batch: 160. Time/Batch: 0.9282. Loss: 0.04778215289115906. Gradient norm: 1.0.
# Training batch: 170. Time/Batch: 4.213. Loss: 0.06347247213125229. Gradient norm: 1.0.
# Training batch: 180. Time/Batch: 5.1899. Loss: 0.05825033411383629. Gradient norm: 1.0.
# Training batch: 190. Time/Batch: 0.3961. Loss: 0.04349571466445923. Gradient norm: 1.0.
# Training batch: 200. Time/Batch: 3.7842. Loss: 0.05436854064464569. Gradient norm: 1.0.
# Training batch: 210. Time/Batch: 3.2981. Loss: 0.041599854826927185. Gradient norm: 1.0.
# Training batch: 220. Time/Batch: 3.2176. Loss: 0.06166484206914902. Gradient norm: 1.0.
# Training batch: 230. Time/Batch: 0.5871. Loss: 0.041491225361824036. Gradient norm: 1.0.
# Training batch: 240. Time/Batch: 0.7455. Loss: 0.045694779604673386. Gradient norm: 1.0.
# Training batch: 250. Time/Batch: 2.829. Loss: 0.12011432647705078. Gradient norm: 1.0.
# Training batch: 260. Time/Batch: 1.0099. Loss: 0.037169959396123886. Gradient norm: 1.0.
# Training batch: 270. Time/Batch: 1.336. Loss: 0.03402867540717125. Gradient norm: 1.0.
# Training batch: 280. Time/Batch: 1.3638. Loss: 0.051642999053001404. Gradient norm: 1.0.
# Training batch: 290. Time/Batch: 3.7914. Loss: 0.05082295462489128. Gradient norm: 1.0.
# Training batch: 300. Time/Batch: 0.604. Loss: 0.055912766605615616. Gradient norm: 1.0.
# Training batch: 310. Time/Batch: 0.8528. Loss: 0.04389866068959236. Gradient norm: 1.0.
# Training batch: 320. Time/Batch: 0.4317. Loss: 0.060542065650224686. Gradient norm: 1.0.
# Training batch: 330. Time/Batch: 0.4397. Loss: 0.06819538027048111. Gradient norm: 1.0.
# Training batch: 340. Time/Batch: 0.7142. Loss: 0.09663528203964233. Gradient norm: 1.0.
# Training batch: 350. Time/Batch: 0.4491. Loss: 0.04238779842853546. Gradient norm: 1.0.
# Training batch: 360. Time/Batch: 0.741. Loss: 0.06139790266752243. Gradient norm: 1.0.
# Training batch: 370. Time/Batch: 2.1079. Loss: 0.049191802740097046. Gradient norm: 1.0.
# Training batch: 380. Time/Batch: 0.8525. Loss: 0.04786575585603714. Gradient norm: 1.0.
# Training batch: 390. Time/Batch: 2.1891. Loss: 0.02424931526184082. Gradient norm: 0.8225284727092939.
# Training batch: 400. Time/Batch: 3.3417. Loss: 0.0539129301905632. Gradient norm: 1.0.
# Training batch: 410. Time/Batch: 2.6825. Loss: 0.03535166755318642. Gradient norm: 1.0.
# Training batch: 420. Time/Batch: 0.3616. Loss: 0.04470057412981987. Gradient norm: 1.0.
# Training batch: 430. Time/Batch: 0.466. Loss: 0.027776354923844337. Gradient norm: 1.0.
# Training batch: 440. Time/Batch: 0.3955. Loss: 0.0712745189666748. Gradient norm: 1.0.
# Training batch: 450. Time/Batch: 4.915. Loss: 0.03793400898575783. Gradient norm: 1.0.
# Training batch: 460. Time/Batch: 2.7757. Loss: 0.05668829753994942. Gradient norm: 1.0.
# Training batch: 470. Time/Batch: 0.5562. Loss: 0.05664213374257088. Gradient norm: 1.0.
# Training batch: 480. Time/Batch: 0.8611. Loss: 0.04759274423122406. Gradient norm: 1.0.
# Training batch: 490. Time/Batch: 0.4092. Loss: 0.09498034417629242. Gradient norm: 1.0.
# Training batch: 500. Time/Batch: 0.8528. Loss: 0.04986925795674324. Gradient norm: 1.0.
# Training batch: 510. Time/Batch: 1.2745. Loss: 0.025361360982060432. Gradient norm: 1.0.
# Training batch: 520. Time/Batch: 3.6752. Loss: 0.05016187205910683. Gradient norm: 1.0.
# Training batch: 530. Time/Batch: 0.4959. Loss: 0.03649343550205231. Gradient norm: 1.0.
# Training batch: 540. Time/Batch: 0.3585. Loss: 0.05839785933494568. Gradient norm: 0.9505874366975304.
# Training batch: 550. Time/Batch: 0.5397. Loss: 0.055729761719703674. Gradient norm: 1.0.
# Training batch: 560. Time/Batch: 0.7498. Loss: 0.030102910473942757. Gradient norm: 1.0.
# Training batch: 570. Time/Batch: 2.6336. Loss: 0.03662203624844551. Gradient norm: 1.0.
# Training batch: 580. Time/Batch: 3.0398. Loss: 0.04757937416434288. Gradient norm: 1.0.
# Training batch: 590. Time/Batch: 0.6954. Loss: 0.03939066082239151. Gradient norm: 0.8771932943581731.
# Training batch: 600. Time/Batch: 3.3138. Loss: 0.03406064957380295. Gradient norm: 0.5540138584261025.
# Training batch: 610. Time/Batch: 0.7554. Loss: 0.04072641581296921. Gradient norm: 1.0.
# Training batch: 620. Time/Batch: 0.438. Loss: 0.03656401485204697. Gradient norm: 1.0.
# Training batch: 630. Time/Batch: 0.3602. Loss: 0.04343375563621521. Gradient norm: 1.0.
# Training batch: 640. Time/Batch: 0.5002. Loss: 0.04111819341778755. Gradient norm: 1.0.
# Training batch: 650. Time/Batch: 0.4321. Loss: 0.020321913063526154. Gradient norm: 1.0.
# Training batch: 660. Time/Batch: 0.8945. Loss: 0.02393817901611328. Gradient norm: 1.0.
# Training batch: 670. Time/Batch: 3.1266. Loss: 0.02091875486075878. Gradient norm: 1.0.
# Training batch: 680. Time/Batch: 0.6615. Loss: 0.028407258912920952. Gradient norm: 1.0.
# Training batch: 690. Time/Batch: 0.4235. Loss: 0.0834190621972084. Gradient norm: 1.0.
# Training batch: 700. Time/Batch: 0.7691. Loss: 0.0571804903447628. Gradient norm: 1.0.
# Training batch: 710. Time/Batch: 3.6043. Loss: 0.06274773180484772. Gradient norm: 1.0.
# Training batch: 720. Time/Batch: 0.7528. Loss: 0.03389068692922592. Gradient norm: 0.9098259653408726.
# Training batch: 730. Time/Batch: 2.9633. Loss: 0.02835947275161743. Gradient norm: 1.0.
# Training batch: 740. Time/Batch: 0.8856. Loss: 0.04429897293448448. Gradient norm: 1.0.
# Training batch: 750. Time/Batch: 1.6927. Loss: 0.04964497312903404. Gradient norm: 1.0.
# Training batch: 760. Time/Batch: 2.4713. Loss: 0.03846542909741402. Gradient norm: 1.0.
# Training batch: 770. Time/Batch: 0.6234. Loss: 0.04525591805577278. Gradient norm: 1.0.
# Testing. Epoch 2
# Testing batch: 0. Time/Batch: 0.4027. Loss: 0.04075131192803383.
# Testing batch: 10. Time/Batch: 0.2731. Loss: 0.041494205594062805.

# %% [markdown]
# ## Visualization
#
# Now, let's view the training loss curve and a sample test dynamics. You can change the grid on which the dynamics are solved to allow the system to run for longer or with smaller/larger steps

# %%
visualization_time=500
kn.set_grids(alpha, visualization_time, 1)

# Get one test batch
for j, batch in enumerate(zip(*[test_dls[key] for key in data_keys])):
    X = {key : x.float().to(device) for (key, (x,_)) in zip(data_keys, batch)}
    Y = {key : y for (key, (_,y)) in zip(data_keys, batch)}
    masks = make_masks(Y,num_classes,device)
    target = batch[0][1].numpy()
    break
# Run
with torch.no_grad():
    kn.eval()
    flow = kn.run(X, full_trajectory=True)
print('Optimized loss: %.04f' % loss_func(flow[burn_in_steps:], masks=masks))
flow = flow.data.cpu().numpy() 
flow %= 2*np.pi

# Plot
fig, axes = plt.subplots(1,2,figsize=(16,8))
all_colors = ['red', 'green', 'blue', 'orange', 'yellow', 'purple', 'pink', 'gray', 'black', 'magenta']
flow_colors = [all_colors[tg] for tg in target]

axes[0].plot(loss_train)
axes[0].set_xlabel('Training iterations', fontsize=16)
axes[0].set_ylabel(r'$L$', fontsize=16)
axes[1].set_prop_cycle('color', flow_colors)
axes[1].plot(flow, alpha=.5)
axes[1].set_xlabel(r'$t$',fontsize=42)
axes[1].set_ylabel(r'$\theta$',fontsize=42)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)

plt.show()
plt.close()
# Out:
# Optimized loss: 0.0346

# %% [markdown]
# ## Animation
#
# Now, we'll plot the dynamics

# %%
# Load original image
img = imread(os.path.join(full_BSDS_path, 'images/{}/{}.jpg'.format('val', dist_names[0])))
h, w, _ = img.shape
subsample = 4
resized = cv.resize(img, (int(w/subsample), int(h/subsample)), interpolation=cv.INTER_NEAREST)
h, w, _ = resized.shape
xx = np.repeat(np.linspace(0,w,w)[None,:], h, axis=0)[:,:,None] / w
yy = np.repeat(np.linspace(0,h,h)[:,None], w, axis=1)[:,:,None] / h
X = np.concatenate([resized / 255, xx, yy], axis=-1).reshape(-1, 5)

X = {data_names[0]:torch.tensor(X).float().to(device)}

kn.set_batch_size(100)
kn.rand_inds=True
kn.set_grids(alpha, 25000, 1)

with torch.no_grad():
    kn.eval()
    flow = kn.run(X, full_trajectory=False)
last_flow = flow[-1]
last_flow = last_flow.cpu().numpy()
last_flow = np.squeeze((last_flow % ((2*np.pi) + 2*np.pi)) % (2*np.pi)).reshape(h, w)
fig, ax = plt.subplots(figsize=(10,10))
plt.imshow(last_flow, cmap='hsv')
plt.gca().axis('off')
plt.show()
# plt.savefig(os.path.join(fig_dir, f'phase_{i_split}.png'))
plt.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.animation import FuncAnimation
from IPython.display import HTML
rc('animation', html='html5')

fig, axes = plt.subplots(1,2,figsize=(8,4))
flow_x         = np.cos(flow)
flow_x_control = np.cos(flow_control)
flow_y         = np.sin(flow)
flow_y_control = np.sin(flow_control)

frames = flow.shape[0]

def update(i):
    for ax, sc, ln, fl, fl_cmp in zip(axes, [scatter0,scatter1],[line0, line1], [flow, flow_control], [[flow_x, flow_y], [flow_x_control, flow_y_control]]):
        angle = fl[i,...].mean()
        state = np.concatenate((fl_cmp[0][i,...].reshape(-1,1), fl_cmp[1][i,...].reshape(-1,1)),axis=-1)
        cv = circular_variance(torch.tensor(fl[i,...])).numpy()
        sc.set_offsets(state)
        ln.set_data([0, (1-cv)*np.cos(angle)],[0, (1-cv)*np.sin(angle)])
    return scatter0,scatter1,line0,line1,


for ax, cl, fl, fl_cmp in zip(axes, ['r','b'],[flow, flow_control], [[flow_x, flow_y], [flow_x_control, flow_y_control]]):
    ax.set_xlim(( -1.25, 1.25))
    ax.set_ylim((-1.25, 1.25))
    scatter = ax.scatter(fl_cmp[0][0,...], fl_cmp[1][0,...], color=cl, alpha=.15)
    angle = fl[0,...].mean()
    state = np.concatenate((fl_cmp[0][0,...].reshape(-1,1), fl_cmp[1][0,...].reshape(-1,1)),axis=-1)
    cv = circular_variance(torch.tensor(fl[0,...])).numpy()
    line, = ax.plot([0, (1-cv)*np.cos(angle)],[0, (1-cv)*np.sin(angle)], color = cl, linewidth = 1)
    lines.append(line)
    scatters.append(scatter)

scatter0 = scatters[0]
scatter1 = scatters[1]
line0 = lines[0]
line1 = lines[1]

anim = FuncAnimation(fig, update, frames=frames, blit=True, interval=20)
html = HTML(anim.to_html5_video())
display(html)
plt.close() # update
# Save
# anim.save(os.path.join(home, 'kuramoto.mp4'), writer='ffmpeg', fps=45)
